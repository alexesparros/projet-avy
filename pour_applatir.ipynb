# %%
import pandas as pd
df= pd.read_csv("vins_vinatis_complet.csv")
import ast

# %%
df.columns
# Out:
# Index(['other_products', 'features', 'advanced_stock_management', 'contenance',
#        'indice_comportementale', 'id', 'affichage_special_pack', 'disponible',
#        'image', 'accroche', 'franco', 'weight', 'active', 'id_manufacturer',
#        'nbvote_product', 'cuvee_type', 'achat_oneshot', 'labels',
#        'online_only', 'id_product_redirected', 'suivi', 'note_sur_20', 'name',
#        'prix_propriete', 'cache_is_pack', 'rewards', 'is_virtual',
#        'out_of_stock', 'note_product', 'additional_shipping_cost',
#        'best_sales', 'physique', 'allocation_annuelle', 'description',
#        'stocks', 'id_cuvee', 'minimal_quantity', 'animations', 'quantity_max',
#        'categories', 'libelle_prix_propriete', 'link_rewrite',
#        'active_description', 'nous_contacter', 'buy_by_multiple',
#        'available_for_order', 'manufacturer_name', 'no_animation',
#        'nutritional_data', 'date_add', 'description_short', 'abv',
#        'cuvee_type_name', 'subtitle_with_link', 'comment', 'providers',
#        'subtitle_without_link', 'prices', 'pricePerLiter', 'id_stock_booked',
#        'image_url'],
#       dtype='object')

# %%
df.head()
# Out:
#                                       other_products  \
# 0  [{'id_image': 94492, 'vintage': 2024, 'id': 72...
# 1  [{'id_image': 95769, 'vintage': 2024, 'id': 73...
# 2  [{'id_image': 93877, 'vintage': 2021, 'id': 57...
# 3  [{'id_image': 80831, 'vintage': 2022, 'id': 63...
# 4  [{'id_image': 98180, 'vintage': 2024, 'id': 75...
#
#                                             features  \
# 0  {'emballage_d_origine': 'AUCUN', 'country': 'F...
# 1  {'country': 'France', 'allergen': False, 'tast...
# 2  {'emballage_d_origine': 'AUCUN', 'country': 'F...
# 3  {'country': 'Italie', 'allergen': False, 'tast...
# 4  {'country': 'France', 'allergen': False, 'tast...
#
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      37  72739
# 1                          0        0.75                      37  73560
# 2                          0        0.75                      37  57419
# 3                          0        0.75                      37  63000
# 4                          0        0.75                      37  75247
#
#    affichage_special_pack  disponible  \
# 0                   False       15213
# 1                   False        4791
# 2                   False        4248
# 3                   False       25798
# 4                   False       11041
#
#                                                image  \
# 0  94492-fine_default/colombard-sauvignon-2024-ho...
# 1  95769-fine_default/le-bal-des-papillons-2024-h...
# 2  93877-fine_default/villa-des-anges-reserve-202...
# 3  80831-fine_default/lupo-meraviglia-tre-di-tre-...
# 4  98180-fine_default/n3-colombard-sauvignon-blan...
#
#                                             accroche  ...   abv  \
# 0  Savoureux <a class="maillage" href ="/vin-d-ho...  ...  11.5
# 1  Plongez dans un univers de légèreté et d’éléga...  ...  11.0
# 2  Un cuvée emblématique de la sélection qui ravi...  ...  14.0
# 3  Une étoile montante des Pouilles vinifiée selo...  ...  14.5
# 4  La référence incontestable des Côtes de <a cla...  ...  11.0
#
#    cuvee_type_name                                 subtitle_with_link  \
# 0           Négoce  <a class="maillage" href ="/achat-vin-sud-oues...
# 1           Négoce  <a class="maillage" href ="/achat-vin-sud-oues...
# 2           Négoce  <a class="maillage" href ="/vin-de-france">Vin...
# 3           Négoce  <a class="maillage" href ="/achat-vin-italie">...
# 4           Négoce  <a class="maillage" href ="/achat-vin-sud-oues...
#
#                                              comment  providers  \
# 0  {'date_add': '2025-04-24 08:16:16', 'wineWaite...      [659]
# 1  {'date_add': '2025-05-11 21:28:22', 'wineWaite...      [659]
# 2  {'date_add': '2025-03-11 20:31:29', 'wineWaite...      [598]
# 3  {'date_add': '2025-04-21 13:38:30', 'wineWaite...      [158]
# 4  {'date_add': '2025-05-06 16:37:28', 'wineWaite...      [253]
#
#                subtitle_without_link  \
# 0  Sud-Ouest / Côtes de Gascogne IGP
# 1  Sud-Ouest / Côtes de Gascogne IGP
# 2                     Vin de France
# 3                Italie / Puglia IGT
# 4  Sud-Ouest / Côtes de Gascogne IGP
#
#                                               prices pricePerLiter  \
# 0  {'discount_quantities': [6], 'best_promo': 15,...          8.80
# 1  {'discount_quantities': [6], 'best_promo': 15,...         11.47
# 2  {'discount_quantities': [2, 6], 'best_promo': ...         12.67
# 3  {'discount_quantities': [3], 'best_promo': 15,...         14.53
# 4  {'discount_quantities': [6], 'best_promo': 12,...          8.67
#
#    id_stock_booked                                          image_url
# 0              NaN  https://www.vinatis.com/72739-detail_default/c...
# 1              NaN  https://www.vinatis.com/73560-detail_default/l...
# 2              NaN  https://www.vinatis.com/57419-detail_default/v...
# 3              NaN  https://www.vinatis.com/63000-detail_default/l...
# 4              NaN  https://www.vinatis.com/75247-detail_default/n...
#
# [5 rows x 61 columns]

# %%
def safe_literal_eval(val):
    if pd.isna(val):
        return {}
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return {}

def flatten_dict_columns(df, columns):
    for col in columns:
        # Convertir en dict de manière sûre
        df[col] = df[col].apply(safe_literal_eval)
        # Aplatir et préfixer
        flat = pd.json_normalize(df[col]).add_prefix(f'{col}_')
        df = pd.concat([df.drop(columns=[col]), flat], axis=1)
    return df

# Utilisation :
cols_to_flatten = ['features','prices','comment','other_products',]  # Ajoute les colonnes à aplatir
df = flatten_dict_columns(df, cols_to_flatten)
df.head()
# Out:
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      37  72739
# 1                          0        0.75                      37  73560
# 2                          0        0.75                      37  57419
# 3                          0        0.75                      37  63000
# 4                          0        0.75                      37  75247
#
#    affichage_special_pack  disponible  \
# 0                   False       15213
# 1                   False        4791
# 2                   False        4248
# 3                   False       25798
# 4                   False       11041
#
#                                                image  \
# 0  94492-fine_default/colombard-sauvignon-2024-ho...
# 1  95769-fine_default/le-bal-des-papillons-2024-h...
# 2  93877-fine_default/villa-des-anges-reserve-202...
# 3  80831-fine_default/lupo-meraviglia-tre-di-tre-...
# 4  98180-fine_default/n3-colombard-sauvignon-blan...
#
#                                             accroche  franco  weight  ...  \
# 0  Savoureux <a class="maillage" href ="/vin-d-ho...   False    1.18  ...
# 1  Plongez dans un univers de légèreté et d’éléga...    True    1.19  ...
# 2  Un cuvée emblématique de la sélection qui ravi...   False    1.26  ...
# 3  Une étoile montante des Pouilles vinifiée selo...    True    1.17  ...
# 4  La référence incontestable des Côtes de <a cla...   False    1.15  ...
#
#    comment_note_sur_20                                   other_products_0  \
# 0                  NaN  {'id_image': 94492, 'vintage': 2024, 'id': 727...
# 1                  NaN  {'id_image': 95769, 'vintage': 2024, 'id': 735...
# 2                  NaN  {'id_image': 93877, 'vintage': 2021, 'id': 574...
# 3                  NaN  {'id_image': 80831, 'vintage': 2022, 'id': 630...
# 4                  NaN  {'id_image': 98180, 'vintage': 2024, 'id': 752...
#
#                                     other_products_1  other_products_2  \
# 0                                               None              None
# 1                                               None              None
# 2  {'id_image': 94693, 'vintage': 2021, 'id': 635...              None
# 3  {'id_image': 86870, 'vintage': 2022, 'id': 666...              None
# 4                                               None              None
#
#    other_products_3 other_products_4  other_products_5  other_products_6  \
# 0              None             None              None              None
# 1              None             None              None              None
# 2              None             None              None              None
# 3              None             None              None              None
# 4              None             None              None              None
#
#    other_products_7  other_products_8
# 0              None              None
# 1              None              None
# 2              None              None
# 3              None              None
# 4              None              None
#
# [5 rows x 127 columns]

# %%
df.describe()
# Out:
#        advanced_stock_management   contenance  indice_comportementale  \
# count                     5067.0  5067.000000             5067.000000
# mean                         0.0     0.941944               11.417012
# std                          0.0     0.732264                7.805495
# min                          0.0     0.250000                1.000000
# 25%                          0.0     0.750000                4.000000
# 50%                          0.0     0.750000               11.000000
# 75%                          0.0     0.750000               16.000000
# max                          0.0     9.000000               37.000000
#
#                  id    disponible       weight  id_manufacturer  \
# count   5067.000000   5067.000000  5067.000000      5067.000000
# mean   66305.490823    198.398855     1.645342      1886.861456
# std    11466.871946    621.715551     1.297428      1348.450630
# min      742.000000    -79.000000     0.490000         0.000000
# 25%    63997.500000     18.000000     1.260000       431.000000
# 50%    70091.000000     60.000000     1.320000      1794.000000
# 75%    73405.500000    193.000000     1.400000      3050.000000
# max    77729.000000  25798.000000    22.810000      4284.000000
#
#        nbvote_product   cuvee_type  achat_oneshot  ...  \
# count     5067.000000  5067.000000    5067.000000  ...
# mean         5.332544     2.581409       0.021512  ...
# std         16.425060     0.818650       0.145097  ...
# min          0.000000     0.000000       0.000000  ...
# 25%          0.000000     2.000000       0.000000  ...
# 50%          1.000000     3.000000       0.000000  ...
# 75%          4.000000     3.000000       0.000000  ...
# max        480.000000     8.000000       1.000000  ...
#
#        features_to_drink_until  features_to_drink_from  prices_best_promo  \
# count              3967.000000              165.000000        5067.000000
# mean               2033.533905             2021.921212           6.173673
# std                   7.536450                3.416224           8.261244
# min                2025.000000             2012.000000           0.000000
# 25%                2028.000000             2020.000000           0.000000
# 50%                2031.000000             2021.000000           0.000000
# 75%                2036.000000             2024.000000          15.000000
# max                2080.000000             2034.000000          34.000000
#
#        prices_best_conditionnement  prices_id_country  prices_price  \
# count                  5067.000000             5067.0   5067.000000
# mean                      1.386225                8.0     75.955613
# std                       0.814781                0.0    768.043725
# min                       1.000000                8.0      4.900000
# 25%                       1.000000                8.0     14.500000
# 50%                       1.000000                8.0     25.100000
# 75%                       2.000000                8.0     50.000000
# max                      12.000000                8.0  43000.000000
#
#        prices_id_group  prices_best_price  comment_source_shop  \
# count           5067.0        5067.000000          3912.000000
# mean               3.0          74.488659             0.164366
# std                0.0         768.078982             0.789750
# min                3.0           4.200770             0.000000
# 25%                3.0          12.900000             0.000000
# 50%                3.0          24.300000             0.000000
# 75%                3.0          48.999600             0.000000
# max                3.0       43000.000000             6.000000
#
#        comment_note_sur_20
# count          1985.000000
# mean             18.130479
# std               0.719545
# min              10.000000
# 25%              18.000000
# 50%              18.000000
# 75%              19.000000
# max              20.000000
#
# [8 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5067 entries, 0 to 5066
# Columns: 127 entries, advanced_stock_management to other_products_8
# dtypes: bool(18), float64(17), int64(22), object(70)
# memory usage: 4.3+ MB

# %%
# Sauvegarde du DataFrame au format CSV
df.to_csv('vins_vinatis_flat_complet.csv', index=False)

# %%
# Out:
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      37  72739
# 1                          0        0.75                      37  73560
# 2                          0        0.75                      37  57419
# 3                          0        0.75                      37  63000
# 4                          0        0.75                      37  75247
#
#    affichage_special_pack  disponible  \
# 0                   False       15213
# 1                   False        4791
# 2                   False        4248
# 3                   False       25798
# 4                   False       11041
#
#                                                image  \
# 0  94492-fine_default/colombard-sauvignon-2024-ho...
# 1  95769-fine_default/le-bal-des-papillons-2024-h...
# 2  93877-fine_default/villa-des-anges-reserve-202...
# 3  80831-fine_default/lupo-meraviglia-tre-di-tre-...
# 4  98180-fine_default/n3-colombard-sauvignon-blan...
#
#                                             accroche  franco  weight  ...  \
# 0  Savoureux <a class="maillage" href ="/vin-d-ho...   False    1.18  ...
# 1  Plongez dans un univers de légèreté et d’éléga...    True    1.19  ...
# 2  Un cuvée emblématique de la sélection qui ravi...   False    1.26  ...
# 3  Une étoile montante des Pouilles vinifiée selo...    True    1.17  ...
# 4  La référence incontestable des Côtes de <a cla...   False    1.15  ...
#
#    comment_note_sur_20                                   other_products_0  \
# 0                  NaN  {'id_image': 94492, 'vintage': 2024, 'id': 727...
# 1                  NaN  {'id_image': 95769, 'vintage': 2024, 'id': 735...
# 2                  NaN  {'id_image': 93877, 'vintage': 2021, 'id': 574...
# 3                  NaN  {'id_image': 80831, 'vintage': 2022, 'id': 630...
# 4                  NaN  {'id_image': 98180, 'vintage': 2024, 'id': 752...
#
#                                     other_products_1  other_products_2  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2  {'id_image': 94693, 'vintage': 2021, 'id': 635...               NaN
# 3  {'id_image': 86870, 'vintage': 2022, 'id': 666...               NaN
# 4                                                NaN               NaN
#
#    other_products_3 other_products_4  other_products_5  other_products_6  \
# 0               NaN              NaN               NaN               NaN
# 1               NaN              NaN               NaN               NaN
# 2               NaN              NaN               NaN               NaN
# 3               NaN              NaN               NaN               NaN
# 4               NaN              NaN               NaN               NaN
#
#    other_products_7  other_products_8
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
#
# [5 rows x 127 columns]

# %%
# Out:
#       id                                           nom  \
# 0  72739           Colombard-Sauvignon 2024 - Horgelus
# 1  73560          Le Bal des Papillons 2024 - Horgelus
# 2  57419  Villa des Anges - Réserve 2021 - Jeff Carrel
# 3  63000      Lupo Meraviglia Tre di Tre 2022 - Botter
# 4  75247    N°3 - Colombard-Sauvignon Blanc 2024 - UBY
#
#                                                 desc  \
# 0  <p>L'harmonieux mariage du colombard et du sau...
# 1  <p>Élaborée avec soin dans le respect des trad...
# 2  <p>La gamme Villa des Anges fait <a class="mai...
# 3  <p>Historiquement, la vinification dans les Po...
# 4  <p>Léger et fruité ! Ce vin <a class="maillage...
#
#                                             accroche  \
# 0  Savoureux <a class="maillage" href ="/vin-d-ho...
# 1  Plongez dans un univers de légèreté et d’éléga...
# 2  Un cuvée emblématique de la sélection qui ravi...
# 3  Une étoile montante des Pouilles vinifiée selo...
# 4  La référence incontestable des Côtes de <a cla...
#
#                                               visuel   producteur  contenance  \
# 0  https://www.vinatis.com/72739-detail_default/c...     Horgelus        0.75
# 1  https://www.vinatis.com/73560-detail_default/l...     Horgelus        0.75
# 2  https://www.vinatis.com/57419-detail_default/v...  Jeff Carrel        0.75
# 3  https://www.vinatis.com/63000-detail_default/l...       Botter        0.75
# 4  https://www.vinatis.com/75247-detail_default/n...          UBY        0.75
#
#    deg_alcool    pays     region  ... cepages millesime  \
# 0        11.5  France  Sud-Ouest  ...     NaN      2024
# 1        11.0  France  Sud-Ouest  ...     NaN      2024
# 2        14.0  France        NaN  ...     NaN      2021
# 3        14.5  Italie   Pouilles  ...     NaN      2022
# 4        11.0  France  Sud-Ouest  ...     NaN      2024
#
#                                              accords  \
# 0  ['Apéritif', 'Entrée', 'Foie gras', 'Fromage',...
# 1  ['Apéritif', 'Entrée', 'Foie gras', 'Fromage',...
# 2  ['Charcuterie', 'Viande rouge', 'Viande blanch...
# 3  ['Apéritif', 'Entrée', 'Charcuterie', 'Viande ...
# 4  ['Apéritif', 'Poisson', 'Coquillage & Crustacé...
#
#                                                 gout  \
# 0  Bouche franchement ronde et fraîche. Finale nette
# 1  Une harmonie parfaite entre vivacité et douceu...
# 2  Bouche élancée, tendue par une fine acidité in...
# 3  Bouche délicate et persistante sur des saveurs...
# 4  L’attaque fraîche et ronde, s'ouvre sur un pal...
#
#                                caractere couleur temp_serv type_produit  bio  \
# 0             Blanc Sec souple et fruité   Blanc      10°C          Vin  NaN
# 1  Blanc Demi-sec, moelleux et liquoreux   Blanc    8-10°C          Vin  NaN
# 2                 Rouge Charnu et fruité   Rouge   14-16°C          Vin  NaN
# 3                 Rouge Charnu et fruité   Rouge   16-18°C          Vin  NaN
# 4                                    NaN   Blanc   10-12°C          Vin  NaN
#
#    prix
# 0   6.6
# 1   8.6
# 2   9.5
# 3  10.9
# 4   6.5
#
# [5 rows x 21 columns]

# %%
# Out:
#                  id   contenance   deg_alcool          prix
# count   5067.000000  5067.000000  4840.000000   5067.000000
# mean   66305.490823     0.941944    13.315950     75.955613
# std    11466.871946     0.732264     1.094836    768.043725
# min      742.000000     0.250000     1.200000      4.900000
# 25%    63997.500000     0.750000    13.000000     14.500000
# 50%    70091.000000     0.750000    13.500000     25.100000
# 75%    73405.500000     0.750000    14.000000     50.000000
# max    77729.000000     9.000000    18.000000  43000.000000

# %%
# Out:
#                                                 nom  \
# id
# 72739           Colombard-Sauvignon 2024 - Horgelus
# 73560          Le Bal des Papillons 2024 - Horgelus
# 57419  Villa des Anges - Réserve 2021 - Jeff Carrel
# 63000      Lupo Meraviglia Tre di Tre 2022 - Botter
# 75247    N°3 - Colombard-Sauvignon Blanc 2024 - UBY
#
#                                                     desc  \
# id
# 72739  <p>L'harmonieux mariage du colombard et du sau...
# 73560  <p>Élaborée avec soin dans le respect des trad...
# 57419  <p>La gamme Villa des Anges fait <a class="mai...
# 63000  <p>Historiquement, la vinification dans les Po...
# 75247  <p>Léger et fruité ! Ce vin <a class="maillage...
#
#                                                 accroche  \
# id
# 72739  Savoureux <a class="maillage" href ="/vin-d-ho...
# 73560  Plongez dans un univers de légèreté et d’éléga...
# 57419  Un cuvée emblématique de la sélection qui ravi...
# 63000  Une étoile montante des Pouilles vinifiée selo...
# 75247  La référence incontestable des Côtes de <a cla...
#
#                                                   visuel   producteur  \
# id
# 72739  https://www.vinatis.com/72739-detail_default/c...     Horgelus
# 73560  https://www.vinatis.com/73560-detail_default/l...     Horgelus
# 57419  https://www.vinatis.com/57419-detail_default/v...  Jeff Carrel
# 63000  https://www.vinatis.com/63000-detail_default/l...       Botter
# 75247  https://www.vinatis.com/75247-detail_default/n...          UBY
#
#        contenance  deg_alcool    pays     region        appellation cepages  \
# id
# 72739        0.75        11.5  France  Sud-Ouest  Côtes de Gascogne     NaN
# 73560        0.75        11.0  France  Sud-Ouest  Côtes de Gascogne     NaN
# 57419        0.75        14.0  France        NaN      Vin de France     NaN
# 63000        0.75        14.5  Italie   Pouilles             Puglia     NaN
# 75247        0.75        11.0  France  Sud-Ouest  Côtes de Gascogne     NaN
#
#       millesime                                            accords  \
# id
# 72739      2024  ['Apéritif', 'Entrée', 'Foie gras', 'Fromage',...
# 73560      2024  ['Apéritif', 'Entrée', 'Foie gras', 'Fromage',...
# 57419      2021  ['Charcuterie', 'Viande rouge', 'Viande blanch...
# 63000      2022  ['Apéritif', 'Entrée', 'Charcuterie', 'Viande ...
# 75247      2024  ['Apéritif', 'Poisson', 'Coquillage & Crustacé...
#
#                                                     gout  \
# id
# 72739  Bouche franchement ronde et fraîche. Finale nette
# 73560  Une harmonie parfaite entre vivacité et douceu...
# 57419  Bouche élancée, tendue par une fine acidité in...
# 63000  Bouche délicate et persistante sur des saveurs...
# 75247  L’attaque fraîche et ronde, s'ouvre sur un pal...
#
#                                    caractere couleur temp_serv type_produit  \
# id
# 72739             Blanc Sec souple et fruité   Blanc      10°C          Vin
# 73560  Blanc Demi-sec, moelleux et liquoreux   Blanc    8-10°C          Vin
# 57419                 Rouge Charnu et fruité   Rouge   14-16°C          Vin
# 63000                 Rouge Charnu et fruité   Rouge   16-18°C          Vin
# 75247                                    NaN   Blanc   10-12°C          Vin
#
#        bio  prix
# id
# 72739  NaN   6.6
# 73560  NaN   8.6
# 57419  NaN   9.5
# 63000  NaN  10.9
# 75247  NaN   6.5

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5067 entries, 72739 to 70578
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nom           5067 non-null   object
#  1   desc          5062 non-null   object
#  2   accroche      5059 non-null   object
#  3   visuel        5050 non-null   object
#  4   producteur    4888 non-null   object
#  5   contenance    5067 non-null   float64
#  6   deg_alcool    4840 non-null   float64
#  7   pays          5026 non-null   object
#  8   region        4812 non-null   object
#  9   appellation   4758 non-null   object
#  10  cepages       2534 non-null   object
#  11  millesime     4701 non-null   object
#  12  accords       4867 non-null   object
#  13  gout          4803 non-null   object
#  14  caractere     4631 non-null   object
#  15  couleur       4938 non-null   object
#  16  temp_serv     4769 non-null   object
#  17  type_produit  5067 non-null   object
#  18  bio           1315 non-null   object
#  19  prix          5067 non-null   float64
# dtypes: float64(3), object(17)
# memory usage: 831.3+ KB
