# %%
import pandas as pd

# %%
df = pd.read_csv("df_clean.csv")
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_19252\685173614.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("df_clean.csv")

# %%
df
# Out:
#                                           name    appid  type required_age  \
# 0                             counter-strike 2      730  game            0
# 1                    grand theft auto v legacy   271590  game           17
# 2                          pubg: battlegrounds   578080  game            0
# 3            tom clancy's rainbow six® siege x   488822  game            0
# 4                                         rust   252490  game            0
# ...                                        ...      ...   ...          ...
# 115407                  the girl in the clouds  3825650  game            0
# 115408                      the elomont raider  3825690  game            0
# 115409                          2 bows 1 arrow  3825740  game            0
# 115410  dungeon parkour block puzzle adventure  3825750  game            0
# 115411                      天工骇客 shadow hacker  3825770  game            0
#
#         is_free controller_support  \
# ...
